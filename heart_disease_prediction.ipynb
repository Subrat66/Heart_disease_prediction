# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv("heart.csv")
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0      52    1   0       125   212    0        1      168      0      1.0  \
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
heart_data = pd.read_csv("heart.csv")

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
heart_data.describe()
# Out:
#                age          sex           cp     trestbps        chol
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000  \
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000  \
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
heart_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# # Count of heart disease presence (0: No disease, 1: Disease)

# %%
print(heart_data['target'].value_counts())
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %% [markdown]
# There are 526 instances where the target variable is '1' (presence of heart disease).
# There are 499 instances where the target variable is '0' (absence of heart disease).

# %% [markdown]
# # Correlation heatmap to visualize the relationships between features

# %%
correlation_matrix = heart_data.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# # Distribution of age among patients with and without heart disease

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=heart_data, x='age', hue='target', bins=20, kde=True)
plt.title("Age Distribution by Heart Disease Presence")
plt.show()

# %%
plt.figure(figsize=(6, 6))
sns.countplot(data=heart_data, x='sex', hue='target')
plt.title("Gender Distribution by Heart Disease Presence")
plt.xticks([0, 1], ['Female', 'Male'])
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=heart_data, x='cp', hue='target')
plt.title("Chest Pain Type Distribution by Heart Disease Presence")
plt.xlabel("Chest Pain Type")
plt.show()

# %%
# Gender distribution among patients with and without heart disease
plt.figure(figsize=(6, 6))
sns.countplot(data=heart_data, x='sex', hue='target')
plt.title("Gender Distribution by Heart Disease Presence")
plt.xticks([0, 1], ['Female', 'Male'])
plt.show()

# %%
# Chest pain type distribution among patients with and without heart disease
plt.figure(figsize=(8, 6))
sns.countplot(data=heart_data, x='cp', hue='target')
plt.title("Chest Pain Type Distribution by Heart Disease Presence")
plt.xlabel("Chest Pain Type")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
heart_data = pd.read_csv("heart.csv")

# %%
# Splitting the data into features (X) and target (y)
X = heart_data.drop(columns=['target'])
y = heart_data['target']

# %%
# Standardize the feature values (mean=0 and variance=1)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the standardized data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
# Model Training

# Logistic Regression
logreg_model = LogisticRegression()
logreg_model.fit(X_train, y_train)
y_pred_logreg = logreg_model.predict(X_test)

# Random Forest Classifier
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

# %%
# Model Evaluation

# Function to evaluate models
def evaluate_model(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    return accuracy, precision, recall, f1

# Evaluate Logistic Regression
accuracy_logreg, precision_logreg, recall_logreg, f1_logreg = evaluate_model(y_test, y_pred_logreg)

# Evaluate Random Forest Classifier
accuracy_rf, precision_rf, recall_rf, f1_rf = evaluate_model(y_test, y_pred_rf)

# %%
# Display results
results = pd.DataFrame({
    'Metric': ['Accuracy', 'Precision', 'Recall', 'F1-Score'],
    'Logistic Regression': [accuracy_logreg, precision_logreg, recall_logreg, f1_logreg],
    'Random Forest': [accuracy_rf, precision_rf, recall_rf, f1_rf]
})

print(results)
# Out:
#       Metric  Logistic Regression  Random Forest
# 0   Accuracy             0.795122       0.985366
# 1  Precision             0.756303       1.000000
# 2     Recall             0.873786       0.970874
# 3   F1-Score             0.810811       0.985222

# %% [markdown]
# From the metrics we got, it appears that the Random Forest model generally outperforms the Logistic Regression model on all fronts – accuracy, precision, recall, and F1-score.
